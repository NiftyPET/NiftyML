# %% [markdown]
# # NiftyML: PET-MR with Machine Learning
#
# [![Version](https://img.shields.io/pypi/v/niftyml.svg?logo=python&logoColor=white)](https://github.com/NiftyPET/NiftyML/releases)|[![Py-Versions](https://img.shields.io/pypi/pyversions/niftyml.svg?logo=python&logoColor=white)](https://pypi.org/project/niftyml)|[![DOI](https://zenodo.org/badge/DOI/10.5281/zenodo.4654096.svg)](https://doi.org/10.5281/zenodo.4654096)|[![Licence](https://img.shields.io/pypi/l/niftyml.svg?label=licence)](https://github.com/NiftyPET/NiftyML/blob/master/LICENCE)|[![Tests](https://img.shields.io/github/workflow/status/NiftyPET/NiftyML/Test?logo=GitHub)](https://github.com/NiftyPET/NiftyML/actions)|[![Coverage](https://codecov.io/gh/NiftyPET/NiftyML/branch/master/graph/badge.svg)](https://codecov.io/gh/NiftyPET/NiftyML)
# -|-|-|-|-|-

# %% [markdown]
# ## Imports
#
# Requires:
#
# ```
# tensorflow-gpu or tensorflow
# niftyml
# matplotlib
# numpy
# tqdm
# ```

# %%
# %matplotlib notebook

import matplotlib.pyplot as plt
import numpy as np
from tqdm.keras import TqdmCallback

from niftypet import ml

# %% [markdown]
# ## Data

# %%
# 20 PET-MR (2 channel) subjects, each 128x128x128
X = np.random.random((20, 128, 128, 128, 2))
Y = np.random.random((20, 128, 128, 128, 1))

# %% [markdown]
# ## Build & Train Model

# %%
model = ml.dcl2021(X.shape[1:])
history = model.fit(
    X[:10], Y[:10],
    validation_split=0.1, epochs=5, batch_size=1,
    verbose=0, callbacks=[TqdmCallback()])

# %%
plt.plot(history.history['nrmse'], label="Training")
plt.plot(history.history['val_nrmse'], label="Validation")
plt.ylabel("NRMSE")
plt.xlabel("epoch")
plt.legend();
# Out:
# <img src="data:image/png;base64,..." width="640">
